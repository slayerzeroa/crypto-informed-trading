# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import glob

# %%
# price_df = pd.DataFrame()

# num = 2018

# for i in range(7):
#     print(num)
#     print(f"test/price/daily/test_daily_price_{num}.csv")
#     temp_price_df = pd.read_csv(f"test/price/daily/test_daily_price_{num}.csv")
#     price_df = pd.concat([price_df, temp_price_df], axis = 0)
#     num += 1

# print(price_df)

# %%
# price_df.to_csv("test/price/daily/test_daily_price_total.csv", index=False)

price_df = pd.read_csv("test/price/daily/test_daily_price_total.csv")
price_df
# Out:
#      Open datetime      Open      High       Low     Close        Volume  \
# 0       2018-01-01  13716.36  13818.55  12750.00  13380.00   8609.915844
# 1       2018-01-02  13382.16  15473.49  12890.02  14675.11  20078.092111
# 2       2018-01-03  14675.11  15307.56  14150.00  14919.51  15905.667639
# 3       2018-01-04  14919.51  15280.00  13918.04  15059.54  21329.649574
# 4       2018-01-05  15059.54  17176.24  14600.00  16960.39  23251.491125
# ...            ...       ...       ...       ...       ...           ...
# 2460    2024-09-26  63152.01  65839.00  62670.00  65173.99  28373.305930
# 2461    2024-09-27  65173.99  66498.00  64819.90  65769.95  22048.804870
# 2462    2024-09-28  65769.95  66260.00  65422.23  65858.00   9127.233160
# 2463    2024-09-29  65858.00  66076.12  65432.00  65602.01   8337.741110
# 2464    2024-09-30  65602.01  65618.80  62856.30  63327.59  30011.087520
#
#       Quote asset volume  Number of trades  Taker buy base asset volume  \
# ...

# %%
price_df['Reversion_Returns'] = price_df['Close'].pct_change(5)

# %%
price_df = price_df.dropna()

# %%
price_df
# Out:
#      Open datetime      Open      High       Low     Close        Volume  \
# 5       2018-01-06  16960.39  17143.13  16011.21  17069.79  18571.457508
# 6       2018-01-07  17069.79  17099.96  15610.00  16150.03  12493.125558
# 7       2018-01-08  16150.03  16322.30  12812.00  14902.54  26600.609912
# 8       2018-01-09  14902.54  15500.00  14011.05  14400.00  14315.004253
# 9       2018-01-10  14401.00  14955.66  13131.31  14907.09  17411.001655
# ...            ...       ...       ...       ...       ...           ...
# 2460    2024-09-26  63152.01  65839.00  62670.00  65173.99  28373.305930
# 2461    2024-09-27  65173.99  66498.00  64819.90  65769.95  22048.804870
# 2462    2024-09-28  65769.95  66260.00  65422.23  65858.00   9127.233160
# 2463    2024-09-29  65858.00  66076.12  65432.00  65602.01   8337.741110
# 2464    2024-09-30  65602.01  65618.80  62856.30  63327.59  30011.087520
#
#       Quote asset volume  Number of trades  Taker buy base asset volume  \
# ...

# %%
price_df['Reversion_Returns_Abs'] = price_df['Reversion_Returns'].abs()
price_df['Reversion_Flag'] = price_df['Reversion_Returns'].apply(lambda x: 1 if x >= 0 else -1)
# Out:
# C:\Users\slaye\AppData\Local\Temp\ipykernel_24936\2833534814.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_df['Reversion_Returns_Abs'] = price_df['Reversion_Returns'].abs()
# C:\Users\slaye\AppData\Local\Temp\ipykernel_24936\2833534814.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_df['Reversion_Flag'] = price_df['Reversion_Returns'].apply(lambda x: 1 if x >= 0 else -1)

# %%
price_df
# Out:
#      Open datetime      Open      High       Low     Close        Volume  \
# 5       2018-01-06  16960.39  17143.13  16011.21  17069.79  18571.457508
# 6       2018-01-07  17069.79  17099.96  15610.00  16150.03  12493.125558
# 7       2018-01-08  16150.03  16322.30  12812.00  14902.54  26600.609912
# 8       2018-01-09  14902.54  15500.00  14011.05  14400.00  14315.004253
# 9       2018-01-10  14401.00  14955.66  13131.31  14907.09  17411.001655
# ...            ...       ...       ...       ...       ...           ...
# 2460    2024-09-26  63152.01  65839.00  62670.00  65173.99  28373.305930
# 2461    2024-09-27  65173.99  66498.00  64819.90  65769.95  22048.804870
# 2462    2024-09-28  65769.95  66260.00  65422.23  65858.00   9127.233160
# 2463    2024-09-29  65858.00  66076.12  65432.00  65602.01   8337.741110
# 2464    2024-09-30  65602.01  65618.80  62856.30  63327.59  30011.087520
#
#       Quote asset volume  Number of trades  Taker buy base asset volume  \
# ...

# %%
price_df['Reversion_Signals'] = price_df['Reversion_Returns_Abs'].apply(lambda x: 1 if x >= 0.1 else 0)
# Out:
# C:\Users\slaye\AppData\Local\Temp\ipykernel_24936\193143112.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_df['Reversion_Signals'] = price_df['Reversion_Returns_Abs'].apply(lambda x: 1 if x >= 0.1 else 0)

# %%
price_df
# Out:
#      Open datetime      Open      High       Low     Close        Volume  \
# 5       2018-01-06  16960.39  17143.13  16011.21  17069.79  18571.457508
# 6       2018-01-07  17069.79  17099.96  15610.00  16150.03  12493.125558
# 7       2018-01-08  16150.03  16322.30  12812.00  14902.54  26600.609912
# 8       2018-01-09  14902.54  15500.00  14011.05  14400.00  14315.004253
# 9       2018-01-10  14401.00  14955.66  13131.31  14907.09  17411.001655
# ...            ...       ...       ...       ...       ...           ...
# 2460    2024-09-26  63152.01  65839.00  62670.00  65173.99  28373.305930
# 2461    2024-09-27  65173.99  66498.00  64819.90  65769.95  22048.804870
# 2462    2024-09-28  65769.95  66260.00  65422.23  65858.00   9127.233160
# 2463    2024-09-29  65858.00  66076.12  65432.00  65602.01   8337.741110
# 2464    2024-09-30  65602.01  65618.80  62856.30  63327.59  30011.087520
#
#       Quote asset volume  Number of trades  Taker buy base asset volume  \
# ...

# %%
price_df['Reversion_Signals_Returns'] = price_df['Reversion_Signals'] * price_df['Reversion_Returns']
# Out:
# C:\Users\slaye\AppData\Local\Temp\ipykernel_24936\4189219683.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_df['Reversion_Signals_Returns'] = price_df['Reversion_Signals'] * price_df['Reversion_Returns']

# %%
price_df['Reversion_Signals'] = price_df['Reversion_Signals'] * price_df['Reversion_Flag']
# Out:
# C:\Users\slaye\AppData\Local\Temp\ipykernel_24936\1539109517.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_df['Reversion_Signals'] = price_df['Reversion_Signals'] * price_df['Reversion_Flag']

# %%
price_df['Reversion_Signals'].value_counts()
# Out:
# Reversion_Signals
#  0    2009
#  1     258
# -1     193
# Name: count, dtype: int64

# %%
price_df.to_csv("test_daily_price_total_reversion_preprocessed.csv", index=False)
