# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import glob
import copy

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

from xgboost import XGBRegressor
from xgboost import XGBClassifier

import statsmodels.api as sm

# %%
np.random.seed(4)

# %%
def preprocess_transaction_flag(df):
    df['transaction_flag'] = df['transaction_count'].apply(lambda x: 1 if x > 0 else 0)
    return df

# %%
# 학습용 데이터 읽기
test_df = pd.read_csv("data/test/test_df.csv")
# test_df

# %%
# target df 읽기

columns = ['date', 'transaction_count', 'transaction_amount', 'transaction_flag']

target_event_receive_df = pd.read_csv("./data/target/event_2_day_transactions_over_100_threshold_3000_receive.csv")
target_event_send_df = pd.read_csv("./data/target/event_2_day_transactions_over_100_threshold_3000_send.csv")

target_event_receive_df = preprocess_transaction_flag(target_event_receive_df)
target_event_send_df = preprocess_transaction_flag(target_event_send_df)

target_event_receive_df.columns = columns
target_event_send_df.columns = columns

# %%
target_event_difference_df = target_event_receive_df.copy()
target_event_difference_df['transaction_count'] = (target_event_receive_df['transaction_count'] - target_event_send_df['transaction_count'])
target_event_difference_df['transaction_amount'] = (target_event_receive_df['transaction_amount'] - target_event_send_df['transaction_amount'])
target_event_difference_df['transaction_flag'] = target_event_difference_df['transaction_amount'].apply(
    lambda x: 1 if x > 0 else (0 if x == 0 else -1)
)
target_event_difference_df
# Out:
#             date  transaction_count  transaction_amount  transaction_flag
# 0     2017-01-01                  0                 0.0                 0
# 1     2017-01-02                  0                 0.0                 0
# 2     2017-01-03                  0                 0.0                 0
# 3     2017-01-04                  0                 0.0                 0
# 4     2017-01-05                  0                 0.0                 0
# ...          ...                ...                 ...               ...
# 2926  2025-01-05                  0                 0.0                 0
# 2927  2025-01-06                  0                 0.0                 0
# 2928  2025-01-07                  0                 0.0                 0
# 2929  2025-01-08                  0                 0.0                 0
# 2930  2025-01-09                  0                 0.0                 0
#
# [2931 rows x 4 columns]

# %%
# 날짜에 맞춰 자르기
start = (test_df['date'].values)[0]
end = (test_df['date'].values)[-1]

def trim_date(df, start, end):
    return df[(df['date']>=start) & (df['date']<=end)]

target_event_receive_df = trim_date(target_event_receive_df, start, end)
target_event_send_df = trim_date(target_event_send_df, start, end)
target_event_difference_df = trim_date(target_event_difference_df, start, end)

# %%
# target 데이터 적용
test_df['transaction_count'] = target_event_receive_df['transaction_count']
test_df['transaction_amount'] = target_event_receive_df['transaction_amount']
test_df['transaction_flag'] = target_event_receive_df['transaction_flag']

test_df['target'] = test_df['transaction_amount']

test_df = test_df.drop(['transaction_count', 'transaction_amount', 'transaction_flag'], axis=1)
test_df.set_index('date', inplace=True)

# %%
sm.tsa.stattools.acf(test_df['target'], nlags=10, fft=False)

fig = plt.figure(figsize=(8,6))
fig.set_facecolor('white')
ax = fig.add_subplot()
sm.graphics.tsa.plot_acf(test_df['target'], lags=10, ax=ax)
plt.show()

# %%
test_df = test_df.fillna(test_df.mean())

shifted_columns = test_df.columns.difference(['target'])
shifted_df = test_df[shifted_columns].shift(1)

shifted_columns = shifted_df.columns + '_shifted'
shifted_df.columns = shifted_columns

combined_df = pd.concat([shifted_df], axis=1)
combined_df['target'] = test_df['target']

# %%
combined_df = combined_df.dropna()
combined_df
# Out:
#             abs_returns_shifted  avg-block-size_shifted  \
# date
# 2017-01-02             0.023098                1.222708
# 2017-01-03             0.041238                0.944878
# 2017-01-04             0.007694                0.906574
# 2017-01-05             0.012969                0.986063
# 2017-01-06             0.017201                0.984197
# ...                         ...                     ...
# 2024-09-26             0.017284                1.714965
# 2024-09-27             0.032018                1.597736
# 2024-09-28             0.009144                1.736523
# 2024-09-29             0.001339                1.775522
# 2024-09-30             0.003887                1.641797
#
#             avg-confirmation-time_shifted  blocks-size_shifted  close_shifted  \
# date
# 2017-01-02                     212.466831        322474.100444        4285.08
# 2017-01-03                     212.466831         97293.875547        4108.37
# 2017-01-04                     212.466831         97444.110856        4139.98
# 2017-01-05                     212.466831         97592.788943        4086.29
# 2017-01-06                     212.466831         97743.656720        4016.00
# ...                                   ...                  ...            ...
# 2024-09-26                     127.525725        603196.813594       63152.01
# 2024-09-27                     190.793990        603443.849853       65173.99
# 2024-09-28                      61.365461        603651.398879       65769.95
# 2024-09-29                      75.537497        603889.347914       65858.00
# 2024-09-30                     127.982783        604118.606257       65602.01
#
#             cost-per-transaction_shifted  \
# date
# 2017-01-02                     77.428762
# 2017-01-03                      7.350606
# 2017-01-04                      7.415466
# 2017-01-05                      7.000531
# 2017-01-06                      6.913398
# ...                                  ...
# 2024-09-26                     57.987881
# 2024-09-27                     56.629444
# 2024-09-28                     63.985187
# 2024-09-29                     53.782789
# 2024-09-30                     47.124922
#
#             cost-per-transaction-percent_shifted  \
# date
# 2017-01-02                              1.280016
# 2017-01-03                              0.763861
# 2017-01-04                              0.656971
# 2017-01-05                              0.537835
# 2017-01-06                              0.355227
# ...                                          ...
# 2024-09-26                              1.280016
# 2024-09-27                              1.280016
# 2024-09-28                              1.280016
# 2024-09-29                              1.280016
# 2024-09-30                              1.280016
#
#             daily_afternoon_returns_shifted  \
# date
# 2017-01-02                         0.000166
# 2017-01-03                         0.000166
# 2017-01-04                         0.000166
# 2017-01-05                         0.000166
# 2017-01-06                         0.000166
# ...                                     ...
# 2024-09-26                        -0.010495
# 2024-09-27                         0.011469
# 2024-09-28                         0.007309
# 2024-09-29                        -0.002505
# 2024-09-30                         0.001919
#
#             daily_afternoon_volatility_shifted  \
# date
# 2017-01-02                            0.000185
# 2017-01-03                            0.000185
# 2017-01-04                            0.000185
# 2017-01-05                            0.000185
# 2017-01-06                            0.000185
# ...                                        ...
# 2024-09-26                            0.000057
# 2024-09-27                            0.000090
# 2024-09-28                            0.000071
# 2024-09-29                            0.000024
# 2024-09-30                            0.000025
#
#             daily_avg_afternoon_returns_shifted  ...  \
# date                                             ...
# 2017-01-02                         6.625148e-09  ...
# 2017-01-03                         6.625148e-09  ...
# 2017-01-04                         6.625148e-09  ...
# 2017-01-05                         6.625148e-09  ...
# 2017-01-06                         6.625148e-09  ...
# ...                                         ...  ...
# 2024-09-26                        -4.868453e-07  ...
# 2024-09-27                         5.319940e-07  ...
# 2024-09-28                         3.396637e-07  ...
# 2024-09-29                        -1.158085e-07  ...
# 2024-09-30                         8.909649e-08  ...
#
#             n-transactions-total_shifted  n-unique-addresses_shifted  \
# date
# 2017-01-02                  5.877181e+08               604537.233636
# 2017-01-03                  1.839618e+08               529709.000000
# 2017-01-04                  1.842534e+08               515024.000000
# 2017-01-05                  1.845561e+08               545609.000000
# 2017-01-06                  1.848845e+08               495910.000000
# ...                                  ...                         ...
# 2024-09-26                  1.085537e+09               513256.000000
# 2024-09-27                  1.086041e+09               515965.000000
# 2024-09-28                  1.086516e+09               549045.000000
# 2024-09-29                  1.086966e+09               477266.000000
# 2024-09-30                  1.087474e+09               462111.000000
#
#             open_shifted  output-volume_shifted  returns_shifted  \
# date
# 2017-01-02       4261.48           1.836027e+06         0.001612
# 2017-01-03       4285.08           1.573982e+06        -0.041238
# 2017-01-04       4108.37           1.950525e+06         0.007694
# 2017-01-05       4139.98           2.482038e+06        -0.012969
# 2017-01-06       4086.29           2.998215e+06        -0.017201
# ...                  ...                    ...              ...
# 2024-09-26      64262.70           8.168643e+05        -0.017284
# 2024-09-27      63152.01           8.415049e+05         0.032018
# 2024-09-28      65173.99           8.076291e+05         0.009144
# 2024-09-29      65769.95           4.624474e+05         0.001339
# 2024-09-30      65858.00           4.892956e+05        -0.003887
#
#             trade-volume_shifted  transaction-fees_shifted  \
# date
# 2017-01-02          3.253403e+08                 83.348399
# 2017-01-03          6.822471e+06                112.884147
# 2017-01-04          8.324526e+06                117.508697
# 2017-01-05          9.340584e+06                193.337436
# 2017-01-06          2.387011e+07                114.991943
# ...                          ...                       ...
# 2024-09-26          3.253403e+08                  6.648910
# 2024-09-27          3.253403e+08                  8.530836
# 2024-09-28          3.253403e+08                 11.071403
# 2024-09-29          3.253403e+08                 10.057609
# 2024-09-30          3.253403e+08                  7.532710
#
#             transaction-fees-usd_shifted  volume_shifted  target
# date
# 2017-01-02                  1.445047e+06      795.150377     0.0
# 2017-01-03                  1.148730e+05     1199.888264     0.0
# 2017-01-04                  1.207600e+05      381.309763     0.0
# 2017-01-05                  2.149023e+05      467.083022     0.0
# 2017-01-06                  1.219580e+05      691.743060     0.0
# ...                                  ...             ...     ...
# 2024-09-26                  4.247346e+05    17813.111680     0.0
# 2024-09-27                  5.680784e+05    28373.305930     0.0
# 2024-09-28                  7.345948e+05    22048.804870  6400.0
# 2024-09-29                  6.675219e+05     9127.233160     0.0
# 2024-09-30                  4.961903e+05     8337.741110     0.0
#
# [2829 rows x 62 columns]

# %%
test_df
# Out:
#              returns     close  abs_returns        volume      open      high  \
# date
# 2017-01-01  0.001612   4285.08     0.023098    795.150377   4261.48   4485.39
# 2017-01-02 -0.041238   4108.37     0.041238   1199.888264   4285.08   4371.52
# 2017-01-03  0.007694   4139.98     0.007694    381.309763   4108.37   4184.69
# 2017-01-04 -0.012969   4086.29     0.012969    467.083022   4139.98   4211.08
# 2017-01-05 -0.017201   4016.00     0.017201    691.743060   4086.29   4119.62
# ...              ...       ...          ...           ...       ...       ...
# 2024-09-26  0.032018  65173.99     0.032018  28373.305930  63152.01  65839.00
# 2024-09-27  0.009144  65769.95     0.009144  22048.804870  65173.99  66498.00
# 2024-09-28  0.001339  65858.00     0.001339   9127.233160  65769.95  66260.00
# 2024-09-29 -0.003887  65602.01     0.003887   8337.741110  65858.00  66076.12
# 2024-09-30 -0.034670  63327.59     0.034670  30011.087520  65602.01  65618.80
#
#                  low  high_low  daily_avg_trades  daily_sum_trades  ...  \
# date                                                                ...
# 2017-01-01   4200.74    284.65         17.258190      1.487585e+06  ...
# 2017-01-02   3938.77    432.75         17.258190      1.487585e+06  ...
# 2017-01-03   3850.00    334.69         17.258190      1.487585e+06  ...
# 2017-01-04   4032.62    178.46         17.258190      1.487585e+06  ...
# 2017-01-05   3911.79    207.83         17.258190      1.487585e+06  ...
# ...              ...       ...               ...               ...  ...
# 2024-09-26  62670.00   3169.00         50.478391      4.361333e+06  ...
# 2024-09-27  64819.90   1678.10         40.492234      3.498529e+06  ...
# 2024-09-28  65422.23    837.77         15.528970      1.341703e+06  ...
# 2024-09-29  65432.00    644.12         16.359363      1.413449e+06  ...
# 2024-09-30  62856.30   2762.50         46.048426      3.978584e+06  ...
#
#             n-transactions  n-unique-addresses  output-volume  trade-volume  \
# date
# 2017-01-01   319896.709677       604537.233636   1.836027e+06  3.253403e+08
# 2017-01-02   290951.000000       529709.000000   1.573982e+06  6.822471e+06
# 2017-01-03   301664.000000       515024.000000   1.950525e+06  8.324526e+06
# 2017-01-04   328642.000000       545609.000000   2.482038e+06  9.340584e+06
# 2017-01-05   288501.000000       495910.000000   2.998215e+06  2.387011e+07
# ...                    ...                 ...            ...           ...
# 2024-09-26   474766.000000       515965.000000   8.415049e+05  3.253403e+08
# 2024-09-27   451723.000000       549045.000000   8.076291e+05  3.253403e+08
# 2024-09-28   507707.000000       477266.000000   4.624474e+05  3.253403e+08
# 2024-09-29   687427.000000       462111.000000   4.892956e+05  3.253403e+08
# 2024-09-30   594224.000000       513555.000000   9.862190e+05  3.253403e+08
#
#             transaction-fees-usd  transaction-fees  n-payments-per-block  \
# date
# 2017-01-01          1.445047e+06         83.348399           4607.731346
# 2017-01-02          1.148730e+05        112.884147           4607.731346
# 2017-01-03          1.207600e+05        117.508697           4607.731346
# 2017-01-04          2.149023e+05        193.337436           4607.731346
# 2017-01-05          1.219580e+05        114.991943           4607.731346
# ...                          ...               ...                   ...
# 2024-09-26          5.680784e+05          8.530836           6348.207692
# 2024-09-27          7.345948e+05         11.071403           6157.496350
# 2024-09-28          6.675219e+05         10.057609           6670.612403
# 2024-09-29          4.961903e+05          7.532710           6508.270968
# 2024-09-30          4.700988e+05          7.329882           6701.992701
#
#               n-payments  avg-confirmation-time  target
# date
# 2017-01-01  6.700324e+05             212.466831     0.0
# 2017-01-02  6.700324e+05             212.466831     0.0
# 2017-01-03  6.700324e+05             212.466831     0.0
# 2017-01-04  6.700324e+05             212.466831     0.0
# 2017-01-05  6.700324e+05             212.466831     0.0
# ...                  ...                    ...     ...
# 2024-09-26  8.252670e+05             190.793990     0.0
# 2024-09-27  8.435770e+05              61.365461     0.0
# 2024-09-28  8.605090e+05              75.537497  6400.0
# 2024-09-29  1.008782e+06             127.982783     0.0
# 2024-09-30  9.181730e+05              84.141097     0.0
#
# [2830 rows x 62 columns]

# %% [markdown]
# ### Target의 Returns 예측

# %%
# 비트코인 이벤트
event_df = pd.read_csv("data/event/bitcoin_event.csv").set_index("Date")
event_df
# Out:
#             Event
# Date
# 2017-01-01      0
# 2017-01-02      0
# 2017-01-03      0
# 2017-01-04      0
# 2017-01-05      0
# ...           ...
# 2024-12-28      0
# 2024-12-29      0
# 2024-12-30      0
# 2024-12-31      0
# 2025-01-01      0
#
# [2923 rows x 1 columns]

# %%
test_df_1 = test_df.copy()
test_df_1['event_flag'] = event_df
test_df_1['event_flag'] = test_df_1['event_flag'].shift(0)

# %%
y = test_df_1['returns'].shift(-2).fillna(test_df_1['returns'].mean()).values
X = test_df_1[['target', 'volume', 'event_flag']].fillna(0)

## train, test 데이터 분리
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, shuffle=False)

X_with_const = sm.add_constant(X_test)

# OLS 회귀 적합
# ---------------------------------------------
lr = sm.OLS(y_test, X_with_const).fit()
print("=== OLS 기본 요약 ===")
print(lr.summary())
# Out:
# === OLS 기본 요약 ===
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                 -0.003
# Method:                 Least Squares   F-statistic:                    0.5544
# Date:                Tue, 11 Feb 2025   Prob (F-statistic):              0.645
# Time:                        17:13:03   Log-Likelihood:                 948.44
# No. Observations:                 425   AIC:                            -1889.
# Df Residuals:                     421   BIC:                            -1873.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0030      0.003      1.168      0.244      -0.002       0.008
# target     -2.611e-08   2.31e-08     -1.128      0.260   -7.16e-08    1.94e-08
# volume     -1.561e-08   6.24e-08     -0.250      0.803   -1.38e-07    1.07e-07
# event_flag    -0.0074      0.013     -0.562      0.574      -0.033       0.018
# ==============================================================================
# Omnibus:                       42.337   Durbin-Watson:                   2.162
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              122.147
# Skew:                           0.446   Prob(JB):                     2.99e-27
# Kurtosis:                       5.470   Cond. No.                     5.75e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.75e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### XGBoost 학습

# %%
# 스케일링
scaler = MinMaxScaler()

scaled_df = pd.DataFrame(scaler.fit_transform(combined_df), columns=combined_df.columns)
scaled_df
# Out:
#       abs_returns_shifted  avg-block-size_shifted  \
# 0                0.058470                0.377989
# 1                0.104388                0.245267
# 2                0.019476                0.226969
# 3                0.032828                0.264942
# 4                0.043543                0.264050
# ...                   ...                     ...
# 2824             0.043751                0.613143
# 2825             0.081047                0.557142
# 2826             0.023147                0.623442
# 2827             0.003389                0.642072
# 2828             0.009839                0.578190
#
#       avg-confirmation-time_shifted  blocks-size_shifted  close_shifted  \
# 0                          0.008012             0.444296       0.015684
# 1                          0.008012             0.000000       0.013155
# 2                          0.008012             0.000296       0.013608
# 3                          0.008012             0.000590       0.012840
# 4                          0.008012             0.000887       0.011834
# ...                             ...                  ...            ...
# 2824                       0.004720             0.998181       0.858044
# 2825                       0.007172             0.998669       0.886977
# 2826                       0.002156             0.999078       0.895505
# 2827                       0.002706             0.999548       0.896765
# 2828                       0.004738             1.000000       0.893102
#
#       cost-per-transaction_shifted  cost-per-transaction-percent_shifted  \
# 0                         0.243694                              0.206983
# 1                         0.005898                              0.110809
# 2                         0.006118                              0.090892
# 3                         0.004710                              0.068694
# 4                         0.004414                              0.034669
# ...                            ...                                   ...
# 2824                      0.177725                              0.206983
# 2825                      0.173116                              0.206983
# 2826                      0.198076                              0.206983
# 2827                      0.163456                              0.206983
# 2828                      0.140864                              0.206983
#
#       daily_afternoon_returns_shifted  daily_afternoon_volatility_shifted  \
# 0                            0.457019                            0.079778
# 1                            0.457019                            0.079778
# 2                            0.457019                            0.079778
# 3                            0.457019                            0.079778
# 4                            0.457019                            0.079778
# ...                               ...                                 ...
# 2824                         0.409553                            0.024584
# 2825                         0.507340                            0.038741
# 2826                         0.488817                            0.030686
# 2827                         0.445128                            0.010555
# 2828                         0.464824                            0.010911
#
#       daily_avg_afternoon_returns_shifted  ...  n-transactions-total_shifted  \
# 0                                0.446828  ...                      0.446874
# 1                                0.446828  ...                      0.000000
# 2                                0.446828  ...                      0.000323
# 3                                0.446828  ...                      0.000658
# 4                                0.446828  ...                      0.001021
# ...                                   ...  ...                           ...
# 2824                             0.443932  ...                      0.997856
# 2825                             0.449911  ...                      0.998414
# 2826                             0.448782  ...                      0.998939
# 2827                             0.446109  ...                      0.999438
# 2828                             0.447312  ...                      1.000000
#
#       n-unique-addresses_shifted  open_shifted  output-volume_shifted  \
# 0                       0.393149      0.015346               0.061314
# 1                       0.296188      0.015684               0.050474
# 2                       0.277159      0.013155               0.066050
# 3                       0.316791      0.013608               0.088036
# 4                       0.252391      0.012840               0.109388
# ...                          ...           ...                    ...
# 2824                    0.274868      0.873937               0.019156
# 2825                    0.278378      0.858044               0.020175
# 2826                    0.321243      0.886977               0.018774
# 2827                    0.228233      0.895505               0.004495
# 2828                    0.208595      0.896765               0.005606
#
#       returns_shifted  trade-volume_shifted  transaction-fees_shifted  \
# 0            0.639711              0.065635                  0.052364
# 1            0.570604              0.001376                  0.072178
# 2            0.649519              0.001679                  0.075280
# 3            0.616196              0.001884                  0.126150
# 4            0.609369              0.004816                  0.073592
# ...               ...                   ...                       ...
# 2824         0.609237              0.065635                  0.000911
# 2825         0.688747              0.065635                  0.002173
# 2826         0.651858              0.065635                  0.003877
# 2827         0.639270              0.065635                  0.003197
# 2828         0.630842              0.065635                  0.001503
#
#       transaction-fees-usd_shifted  volume_shifted    target
# 0                         0.017250        0.000746  0.000000
# 1                         0.000829        0.001279  0.000000
# 2                         0.000902        0.000202  0.000000
# 3                         0.002064        0.000314  0.000000
# 4                         0.000916        0.000610  0.000000
# ...                            ...             ...       ...
# 2824                      0.004654        0.023139  0.000000
# 2825                      0.006424        0.037034  0.000000
# 2826                      0.008480        0.028712  0.000257
# 2827                      0.007651        0.011710  0.000000
# 2828                      0.005536        0.010671  0.000000
#
# [2829 rows x 62 columns]

# %%
y = scaled_df['target'].values
X = scaled_df.drop('target', axis=1)

# %%
## train, test 데이터 분리
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=False)

# %%
# shift 1, Linear Regression
lr = LinearRegression(fit_intercept=True)
lr.fit(X_train, y_train)
print('훈련 세트 R2 :', lr.score(X_train, y_train))

# 테스트 셋 예측
lr_y_pred = lr.predict(X_test)

# 정확도
predict_df = pd.DataFrame({'y_test': y_test, 'y_pred': lr_y_pred})
predict_df['diff'] = predict_df['y_test'] - predict_df['y_pred']
predict_df['diff_abs'] = predict_df['diff'].abs()
predict_df['diff_squared'] = predict_df['diff']**2
print("MAE:", predict_df['diff_abs'].mean())
print("MSE:", predict_df['diff_squared'].mean())
print("R2:", lr.score(X_test, y_test))
# Out:
# 훈련 세트 R2 : 0.1449960090681921
# MAE: 0.027233712006527747
# MSE: 0.0013471291791720243
# R2: -107.70333918906475

# %%
# 현재 모델
XGBR = XGBRegressor(n_estimators=10000, gamma=0.002, subsample=0.75, learning_rate=0.07, max_depth=3, objective='reg:squarederror')
XGBR.fit(X_train, y_train)

predict_df = pd.DataFrame({'y_test': y_test, 'y_pred': XGBR.predict(X_test)})
predict_df['diff'] = predict_df['y_test'] - predict_df['y_pred']
predict_df['diff_abs'] = predict_df['diff'].abs()
predict_df['diff_squared'] = predict_df['diff']**2
print("MAE:", predict_df['diff_abs'].mean())
print("MSE:", predict_df['diff_squared'].mean())
print("R2:", XGBR.score(X_test, y_test))

XGBR.save_model('models/xgb_model_event_informed_amount_250211.json')
# Out:
# MAE: 0.004528073153053321
# MSE: 0.00037516351656113547
# R2: -29.27291489385796

# %%
# 모델 불러오기
XGBR = XGBRegressor()
XGBR.load_model('models/xgb_model_event_informed_amount_250211.json')

# Error, R2 평가
predict_df = pd.DataFrame({'y_test': y_test, 'y_pred': XGBR.predict(X_test)})
predict_df['diff'] = predict_df['y_test'] - predict_df['y_pred']
predict_df['diff_abs'] = predict_df['diff'].abs()
predict_df['diff_squared'] = predict_df['diff']**2
print("MAE:", predict_df['diff_abs'].mean())
print("MSE:", predict_df['diff_squared'].mean())
print("R2:", XGBR.score(X_test, y_test))
# Out:
# MAE: 0.004528073153053321
# MSE: 0.00037516351656113547
# R2: -29.27291489385796

# %%
xxx_amount = XGBR.predict(X)
test_X = copy.deepcopy(X)
test_X['ITI_amount'] = xxx_amount
test_X.index = combined_df.index
test_X
# Out:
#             abs_returns_shifted  avg-block-size_shifted  \
# date
# 2017-01-02             0.058470                0.377989
# 2017-01-03             0.104388                0.245267
# 2017-01-04             0.019476                0.226969
# 2017-01-05             0.032828                0.264942
# 2017-01-06             0.043543                0.264050
# ...                         ...                     ...
# 2024-09-26             0.043751                0.613143
# 2024-09-27             0.081047                0.557142
# 2024-09-28             0.023147                0.623442
# 2024-09-29             0.003389                0.642072
# 2024-09-30             0.009839                0.578190
#
#             avg-confirmation-time_shifted  blocks-size_shifted  close_shifted  \
# date
# 2017-01-02                       0.008012             0.444296       0.015684
# 2017-01-03                       0.008012             0.000000       0.013155
# 2017-01-04                       0.008012             0.000296       0.013608
# 2017-01-05                       0.008012             0.000590       0.012840
# 2017-01-06                       0.008012             0.000887       0.011834
# ...                                   ...                  ...            ...
# 2024-09-26                       0.004720             0.998181       0.858044
# 2024-09-27                       0.007172             0.998669       0.886977
# 2024-09-28                       0.002156             0.999078       0.895505
# 2024-09-29                       0.002706             0.999548       0.896765
# 2024-09-30                       0.004738             1.000000       0.893102
#
#             cost-per-transaction_shifted  \
# date
# 2017-01-02                      0.243694
# 2017-01-03                      0.005898
# 2017-01-04                      0.006118
# 2017-01-05                      0.004710
# 2017-01-06                      0.004414
# ...                                  ...
# 2024-09-26                      0.177725
# 2024-09-27                      0.173116
# 2024-09-28                      0.198076
# 2024-09-29                      0.163456
# 2024-09-30                      0.140864
#
#             cost-per-transaction-percent_shifted  \
# date
# 2017-01-02                              0.206983
# 2017-01-03                              0.110809
# 2017-01-04                              0.090892
# 2017-01-05                              0.068694
# 2017-01-06                              0.034669
# ...                                          ...
# 2024-09-26                              0.206983
# 2024-09-27                              0.206983
# 2024-09-28                              0.206983
# 2024-09-29                              0.206983
# 2024-09-30                              0.206983
#
#             daily_afternoon_returns_shifted  \
# date
# 2017-01-02                         0.457019
# 2017-01-03                         0.457019
# 2017-01-04                         0.457019
# 2017-01-05                         0.457019
# 2017-01-06                         0.457019
# ...                                     ...
# 2024-09-26                         0.409553
# 2024-09-27                         0.507340
# 2024-09-28                         0.488817
# 2024-09-29                         0.445128
# 2024-09-30                         0.464824
#
#             daily_afternoon_volatility_shifted  \
# date
# 2017-01-02                            0.079778
# 2017-01-03                            0.079778
# 2017-01-04                            0.079778
# 2017-01-05                            0.079778
# 2017-01-06                            0.079778
# ...                                        ...
# 2024-09-26                            0.024584
# 2024-09-27                            0.038741
# 2024-09-28                            0.030686
# 2024-09-29                            0.010555
# 2024-09-30                            0.010911
#
#             daily_avg_afternoon_returns_shifted  ...  \
# date                                             ...
# 2017-01-02                             0.446828  ...
# 2017-01-03                             0.446828  ...
# 2017-01-04                             0.446828  ...
# 2017-01-05                             0.446828  ...
# 2017-01-06                             0.446828  ...
# ...                                         ...  ...
# 2024-09-26                             0.443932  ...
# 2024-09-27                             0.449911  ...
# 2024-09-28                             0.448782  ...
# 2024-09-29                             0.446109  ...
# 2024-09-30                             0.447312  ...
#
#             n-transactions-total_shifted  n-unique-addresses_shifted  \
# date
# 2017-01-02                      0.446874                    0.393149
# 2017-01-03                      0.000000                    0.296188
# 2017-01-04                      0.000323                    0.277159
# 2017-01-05                      0.000658                    0.316791
# 2017-01-06                      0.001021                    0.252391
# ...                                  ...                         ...
# 2024-09-26                      0.997856                    0.274868
# 2024-09-27                      0.998414                    0.278378
# 2024-09-28                      0.998939                    0.321243
# 2024-09-29                      0.999438                    0.228233
# 2024-09-30                      1.000000                    0.208595
#
#             open_shifted  output-volume_shifted  returns_shifted  \
# date
# 2017-01-02      0.015346               0.061314         0.639711
# 2017-01-03      0.015684               0.050474         0.570604
# 2017-01-04      0.013155               0.066050         0.649519
# 2017-01-05      0.013608               0.088036         0.616196
# 2017-01-06      0.012840               0.109388         0.609369
# ...                  ...                    ...              ...
# 2024-09-26      0.873937               0.019156         0.609237
# 2024-09-27      0.858044               0.020175         0.688747
# 2024-09-28      0.886977               0.018774         0.651858
# 2024-09-29      0.895505               0.004495         0.639270
# 2024-09-30      0.896765               0.005606         0.630842
#
#             trade-volume_shifted  transaction-fees_shifted  \
# date
# 2017-01-02              0.065635                  0.052364
# 2017-01-03              0.001376                  0.072178
# 2017-01-04              0.001679                  0.075280
# 2017-01-05              0.001884                  0.126150
# 2017-01-06              0.004816                  0.073592
# ...                          ...                       ...
# 2024-09-26              0.065635                  0.000911
# 2024-09-27              0.065635                  0.002173
# 2024-09-28              0.065635                  0.003877
# 2024-09-29              0.065635                  0.003197
# 2024-09-30              0.065635                  0.001503
#
#             transaction-fees-usd_shifted  volume_shifted  ITI_amount
# date
# 2017-01-02                      0.017250        0.000746    0.000818
# 2017-01-03                      0.000829        0.001279    0.010080
# 2017-01-04                      0.000902        0.000202    0.004932
# 2017-01-05                      0.002064        0.000314    0.024358
# 2017-01-06                      0.000916        0.000610    0.022549
# ...                                  ...             ...         ...
# 2024-09-26                      0.004654        0.023139    0.004729
# 2024-09-27                      0.006424        0.037034    0.004357
# 2024-09-28                      0.008480        0.028712    0.004357
# 2024-09-29                      0.007651        0.011710    0.004729
# 2024-09-30                      0.005536        0.010671   -0.000701
#
# [2829 rows x 62 columns]

# %%
test_X[['ITI_amount']].to_csv("data/iti/event_ITI_amount_250211.csv", index=True)

# %%
ITI_amount = pd.read_csv("data/iti/event_ITI_amount_250211.csv")
ITI_amount = ITI_amount.set_index('date')
ITI_amount
# Out:
#             ITI_amount
# date
# 2017-01-02    0.000818
# 2017-01-03    0.010080
# 2017-01-04    0.004932
# 2017-01-05    0.024358
# 2017-01-06    0.022549
# ...                ...
# 2024-09-26    0.004729
# 2024-09-27    0.004357
# 2024-09-28    0.004357
# 2024-09-29    0.004729
# 2024-09-30   -0.000701
#
# [2829 rows x 1 columns]

# %% [markdown]
# ### 기존 Target 예측

# %%
# 실제 트레이딩 확인 (변수명은 그대로)
reversion_df = target_event_receive_df.copy()
reversion_df = reversion_df[['date', 'transaction_amount']]
reversion_df.columns = ['date', 'target']
reversion_df = reversion_df.set_index('date')

# 내일 target 예측
reversion_df = reversion_df.shift(-1).dropna()
reversion_df
# Out:
#             target
# date
# 2017-01-01     0.0
# 2017-01-02     0.0
# 2017-01-03     0.0
# 2017-01-04     0.0
# 2017-01-05     0.0
# ...            ...
# 2024-09-25     0.0
# 2024-09-26     0.0
# 2024-09-27  6400.0
# 2024-09-28     0.0
# 2024-09-29     0.0
#
# [2829 rows x 1 columns]

# %%
result_df = pd.concat([ITI_amount, reversion_df], axis=1)
result_df = result_df.dropna()

# %%
result_df
# Out:
#             ITI_amount        target
# date
# 2017-01-02    0.000818  0.000000e+00
# 2017-01-03    0.010080  0.000000e+00
# 2017-01-04    0.004932  0.000000e+00
# 2017-01-05    0.024358  0.000000e+00
# 2017-01-06    0.022549  1.711156e+06
# ...                ...           ...
# 2024-09-25    0.004357  0.000000e+00
# 2024-09-26    0.004729  0.000000e+00
# 2024-09-27    0.004357  6.400000e+03
# 2024-09-28    0.004357  0.000000e+00
# 2024-09-29    0.004729  0.000000e+00
#
# [2828 rows x 2 columns]

# %%
y = result_df['target'].values
X = result_df['ITI_amount']

## train, test 데이터 분리
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=False, random_state=0)

# %%
X_with_const = sm.add_constant(X_test)

# OLS 회귀 적합
# ---------------------------------------------
lr = sm.OLS(y_test, X_with_const).fit()
# print("=== OLS 기본 요약 ===")
# print(lr.summary())

# 로버스트 공분산(이분산 robust: HC1) 적용
# ---------------------------------------------
lr_hc1 = lr.get_robustcov_results(cov_type='HC1')
print("\n=== 로버스트(HC1) 요약 ===")
print(lr_hc1.summary())
# Out:
# === 로버스트(HC1) 요약 ===
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                     3.485
# Date:                Tue, 11 Feb 2025   Prob (F-statistic):             0.0623
# Time:                        17:13:09   Log-Likelihood:                -10867.
# No. Observations:                 849   AIC:                         2.174e+04
# Df Residuals:                     847   BIC:                         2.175e+04
# Df Model:                           1
# Covariance Type:                  HC1
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        1.39e+04   3072.053      4.524      0.000    7869.734    1.99e+04
# ITI_amount -7.015e+04   3.76e+04     -1.867      0.062   -1.44e+05    3601.436
# ==============================================================================
# Omnibus:                     1393.979   Durbin-Watson:                   1.513
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           582285.978
# Skew:                          10.254   Prob(JB):                         0.00
# Kurtosis:                     129.648   Cond. No.                         53.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)

# %% [markdown]
# ### Returns 예측

# %%
test_target_df = test_df['returns'].shift(-3).dropna()


test_target_df = pd.concat([ITI_amount, test_target_df], axis=1)
test_target_df = test_target_df.dropna()

test_target_df.columns = ['ITI_amount', 'target']
test_target_df
# Out:
#             ITI_amount    target
# date
# 2017-01-02    0.000818 -0.017201
# 2017-01-03    0.010080  0.005976
# 2017-01-04    0.004932  0.018319
# 2017-01-05    0.024358  0.049101
# 2017-01-06    0.022549 -0.008186
# ...                ...       ...
# 2024-09-23    0.004729  0.032018
# 2024-09-24    0.004357  0.009144
# 2024-09-25    0.004357  0.001339
# 2024-09-26    0.004729 -0.003887
# 2024-09-27    0.004357 -0.034670
#
# [2826 rows x 2 columns]

# %%
y = test_target_df['target'].values
X = test_target_df[['ITI_amount']]

## train, test 데이터 분리
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, shuffle=False, random_state=0)

X_with_const = sm.add_constant(X_test)

# OLS 회귀 적합
# ---------------------------------------------
lr = sm.OLS(y_test, X_with_const).fit()
# print("=== OLS 기본 요약 ===")
# print(lr.summary())

# 로버스트 공분산(이분산 robust: HC1) 적용
# ---------------------------------------------
lr_hc1 = lr.get_robustcov_results(cov_type='HC1')
print("\n=== 로버스트(HC1) 요약 ===")
print(lr_hc1.summary())
# Out:
# === 로버스트(HC1) 요약 ===
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                     9.261
# Date:                Tue, 11 Feb 2025   Prob (F-statistic):            0.00249
# Time:                        17:13:09   Log-Likelihood:                 945.34
# No. Observations:                 424   AIC:                            -1887.
# Df Residuals:                     422   BIC:                            -1879.
# Df Model:                           1
# Covariance Type:                  HC1
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0025      0.001      1.932      0.054   -4.24e-05       0.005
# ITI_amount    -0.0478      0.016     -3.043      0.002      -0.079      -0.017
# ==============================================================================
# Omnibus:                       42.500   Durbin-Watson:                   2.146
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              128.037
# Skew:                           0.433   Prob(JB):                     1.57e-28
# Kurtosis:                       5.549   Cond. No.                         38.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)

# %% [markdown]
# ### Event 예측

# %%
# 비트코인 이벤트
event_df = pd.read_csv("data/event/bitcoin_event.csv")

# %%
test_target_df = test_df['returns'].shift(-2).dropna()


test_target_df = pd.concat([ITI_amount, test_target_df], axis=1)
test_target_df = test_target_df.dropna()

test_target_df.columns = ['ITI_amount', 'target']
test_target_df
# Out:
#             ITI_amount    target
# date
# 2017-01-02    0.000818 -0.012969
# 2017-01-03    0.010080 -0.017201
# 2017-01-04    0.004932  0.005976
# 2017-01-05    0.024358  0.018319
# 2017-01-06    0.022549  0.049101
# ...                ...       ...
# 2024-09-24    0.004357  0.032018
# 2024-09-25    0.004357  0.009144
# 2024-09-26    0.004729  0.001339
# 2024-09-27    0.004357 -0.003887
# 2024-09-28    0.004357 -0.034670
#
# [2827 rows x 2 columns]

# %%
test_target_receive_df = target_event_receive_df.set_index('date').copy()

# %%
# 실제값 이벤트 예측용
test_target_df['transaction_amount'] = test_target_receive_df['transaction_amount']
test_target_df['transaction_count'] = test_target_receive_df['transaction_count']
test_target_df['transaction_flag'] = test_target_receive_df['transaction_flag']

test_target_df['transaction_amount'] = test_target_df['transaction_amount'].apply(lambda x: 0.000001 if x == 0 else x)
test_target_df['transaction_amount_returns'] = test_target_df['transaction_amount'].pct_change(1).fillna(0)

# %%
event_df = event_df.set_index('Date')

# %%
test_target_df['event_flag'] = (event_df[(event_df.index>=list(test_target_df.index)[0])&(event_df.index<=list(test_target_df.index)[-1])]['Event'])
test_target_df
# Out:
#             ITI_amount    target  transaction_amount  transaction_count  \
# date
# 2017-01-02    0.000818 -0.012969            0.000001                  0
# 2017-01-03    0.010080 -0.017201            0.000001                  0
# 2017-01-04    0.004932  0.005976            0.000001                  0
# 2017-01-05    0.024358  0.018319            0.000001                  0
# 2017-01-06    0.022549  0.049101            0.000001                  0
# ...                ...       ...                 ...                ...
# 2024-09-24    0.004357  0.032018            0.000001                  0
# 2024-09-25    0.004357  0.009144            0.000001                  0
# 2024-09-26    0.004729  0.001339            0.000001                  0
# 2024-09-27    0.004357 -0.003887            0.000001                  0
# 2024-09-28    0.004357 -0.034670         6400.000000                  2
#
#             transaction_flag  transaction_amount_returns  event_flag
# date
# 2017-01-02                 0                0.000000e+00           0
# 2017-01-03                 0                0.000000e+00           0
# 2017-01-04                 0                0.000000e+00           0
# 2017-01-05                 0                0.000000e+00           0
# 2017-01-06                 0                0.000000e+00           0
# ...                      ...                         ...         ...
# 2024-09-24                 0                0.000000e+00           0
# 2024-09-25                 0                0.000000e+00           0
# 2024-09-26                 0                0.000000e+00           0
# 2024-09-27                 0                0.000000e+00           0
# 2024-09-28                 1                6.400000e+09           0
#
# [2827 rows x 7 columns]

# %%
pd.set_option('display.max_rows', None)

# %%
pp = test_target_df[test_target_df['event_flag']==1]
pplen = len(pp)

pp2 = pp[pp['transaction_flag'] == 1]

pp2len = len(pp2)


pp2len/pplen
# Out:
# 0.22058823529411764

# %%
pp = test_target_df[test_target_df['transaction_flag']==1]
pplen = len(pp)

pp2 = pp[pp['event_flag'] == 1]

pp2len = len(pp2)


pp2len/pplen
# Out:
# 0.062370062370062374
